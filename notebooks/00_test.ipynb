# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve() / "src"))

# %%
from market_extractor.utils.math_utils import add, multiply

print(add(1, 2))

print(multiply(2, 3))
# Out:
# 3
# 6
