# %% [markdown]
# # Init Healthcheck

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve() / "src"))

from market_extractor.db._engine import make_engine, health_check

engine = make_engine()

health_check(engine)
# Out:
# ['core.market', 'core.ticker', 'data.ohlcv']
