# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve() / "src"))

# %%
# Ticker
from market_extractor.providers.yfinance import Ticker

ticker = Ticker("AAPL")
ticker.get_data(from_date="2025-01-01")

# %%
# Tickers
from market_extractor.providers.yfinance import Tickers

tickers = Tickers(["AAPL", "MSFT", "GOOG"])
tickers.news

# %%
# Market
from market_extractor.providers.yfinance import Market

market = Market("EUROPE")
# market.status
market.summary

# %%
# Calendars
from market_extractor.providers.yfinance import Calendar

calendar = Calendar(start_date="2021-01-01", end_date="2021-12-31")
# calendar.earnings_calendar()
# calendar.economic_events("2026-02-26", "2022-03-08")
# calendar.ipo_info("2026-02-26", "2026-03-08")
calendar.splits_calendar("2026-02-26", "2026-03-08")
# Out:
#                                     Company                Payable On  \
# Symbol
# 4957.T             Yasuhara Chemical Co Ltd 2026-03-06 05:00:00+00:00
# CISTRO.BO               Cistro Telelink Ltd 2026-03-06 05:00:00+00:00
# LKPFIN.BO                   LKP Finance Ltd 2026-03-06 05:00:00+00:00
# MEERA.BO               Meera Industries Ltd 2026-03-06 05:00:00+00:00
# SILVERTUC.BO  Silver Touch Technologies Ltd 2026-03-06 05:00:00+00:00
# SILVERTUC.NS  Silver Touch Technologies Ltd 2026-03-06 05:00:00+00:00
# 7946.N                          Koyosha Inc 2026-03-05 05:00:00+00:00
# 7946.T                          Koyosha Inc 2026-03-05 05:00:00+00:00
# AQYLON.BO                  Aqylon Nexus Ltd 2026-03-05 05:00:00+00:00
# AQYLON.NS                  Aqylon Nexus Ltd 2026-03-05 05:00:00+00:00
# BHLL                Bunker Hill Mining Corp 2026-03-05 05:00:00+00:00
# BNKR.V              Bunker Hill Mining Corp 2026-03-05 05:00:00+00:00
#
#               Optionable  Old Share Worth  Share Worth
# Symbol
# 4957.T             False          1186560            1
# CISTRO.BO          False               10            6
# LKPFIN.BO          False                1            5
# MEERA.BO           False                1            2
# SILVERTUC.BO       False                1            2
# SILVERTUC.NS       False                1            2
# 7946.N             False                1            5
# 7946.T             False                1            5
# AQYLON.BO          False                1           10
# AQYLON.NS          False                1           10
# BHLL               False               35            1
# BNKR.V             False               35            1
