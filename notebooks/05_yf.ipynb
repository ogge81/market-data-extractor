# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve() / "src"))

# %%
# Ticker
from market_extractor.providers.yfinance import Ticker

ticker = Ticker("AAPL")
ticker.get_data(from_date="2025-01-01")

# %%
# Tickers
from market_extractor.providers.yfinance import Tickers

tickers = Tickers(["AAPL", "MSFT", "GOOG"])
tickers.news

# %%
# Market
from market_extractor.providers.yfinance import Market

market = Market("EUROPE")
# market.status
market.summary

# %%
# Calendars
from market_extractor.providers.yfinance import Calendar

calendar = Calendar(start_date="2021-01-01", end_date="2021-12-31")
# calendar.earnings_calendar()
# calendar.economic_events("2026-02-26", "2022-03-08")
# calendar.ipo_info("2026-02-26", "2026-03-08")
calendar.splits_calendar("2026-02-26", "2026-03-08")

# %%
# Seeker

from market_extractor.providers.yfinance import Seeker

seeker = Seeker("Gold")
seeker.lookup("AAPL", type="stock", count=10)

# %%
# Sector
from market_extractor.providers.yfinance import Sector

sector = Sector("basic-materials")
sector.industries
# sector.key
# sector.name

# %%
# Industry
from market_extractor.providers.yfinance import Industry

industry = Industry("aluminum")
# industry.key
# industry.name
industry.top_growth_companies
# Out:
#                                name  ytd return  growth estimate
# symbol
# CENX       Century Aluminum Company      0.3326         2.030303
# KALU    Kaiser Aluminum Corporation      0.1410        -0.040146
# CSTM                 Constellium SE      0.3767        -0.161170
# AA                Alcoa Corporation      0.1944        -1.365639
